# %%
import CococoNet_reader
import pandas as pd

# %%
human_net = CococoNet_reader.read_cococonet('human')

# %%
human_net
# Out:
#                  ENSG00000278267  ENSG00000233750  ENSG00000268903  \
# ENSG00000278267         1.000000         0.343890         0.487717
# ENSG00000233750         0.343890         1.000000         0.860658
# ENSG00000268903         0.487717         0.860658         1.000000
# ENSG00000269981         0.504516         0.809451         0.946427
# ENSG00000241860         0.479969         0.673940         0.811533
# ...                          ...              ...              ...
# ENSG00000276345         0.085152         0.055478         0.092469
# ENSG00000277856         0.025113         0.045883         0.077274
# ENSG00000275063         0.005367         0.013963         0.031017
# ENSG00000278817         0.458116         0.154940         0.374283
# ENSG00000277196         0.389884         0.049407         0.242737
#
#                  ENSG00000269981  ENSG00000241860  ENSG00000279928  \
# ENSG00000278267         0.504516         0.479969         0.343116
# ...

# %%
top_200_ttc7b = human_net.loc['ENSG00000165914'].sort_values(ascending= False).head(201)

# %%
top_200_ttc7b.to_csv("/data/passala/git/Preeclampsia_analysis/top_200_ttc7b_coepxression_partners.csv")

# %%
top_200_ttc7b
# Out:
# ENSG00000165914    1.000000
# ENSG00000078369    0.982210
# ENSG00000170027    0.969011
# ENSG00000138801    0.963380
# ENSG00000259330    0.962912
#                      ...
# ENSG00000170035    0.938604
# ENSG00000186318    0.938554
# ENSG00000143164    0.938357
# ENSG00000153885    0.938332
# ENSG00000125386    0.938304
# Name: ENSG00000165914, Length: 201, dtype: float64
